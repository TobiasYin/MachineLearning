# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# %%
from sklearn.datasets import fetch_lfw_people

# %%
faces = fetch_lfw_people()

# %%
faces.images[1,:,:].shape
# Out:
# (62, 47)

# %%
faces.data.shape
# Out:
# (13233, 2914)

# %%
plt.imshow(255 - faces.images[2100,:,:], cmap = matplotlib.cm.binary)

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(svd_solver="randomized")
pca.fit(faces.data)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=None, random_state=None,
#   svd_solver='randomized', tol=0.0, whiten=False)

# %%
pca.components_.shape
# Out:
# (2914, 2914)

# %%
plt.imshow(255 - pca.components_[64,:].reshape(62,-1), cmap = matplotlib.cm.binary)
plt.show()

# %%
faces2 = fetch_lfw_people(min_faces_per_person=60)

# %%
faces2.data.shape
# Out:
# (1348, 2914)

# %%
plt.imshow(255 - faces2.data[61,:].reshape(62,-1), cmap = matplotlib.cm.binary)
plt.show()
