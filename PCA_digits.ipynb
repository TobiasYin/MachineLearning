# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets

# %%
digits = datasets.load_digits()
x = digits.data
y = digits.target

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
# %%timeit
knn_clf = KNeighborsClassifier()
knn_clf.fit(x_train, y_train)
knn_clf.score(x_test,y_test)
# Out:
# 73.9 ms ± 752 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
from sklearn.decomposition import PCA
pca = PCA(0.95)
pca.fit(x)
x_pca = pca.transform(x)
x_trainp, x_testp, y_trainp, y_testp = train_test_split(x_pca,y)

# %%
# %%timeit
knn_clf = KNeighborsClassifier()
knn_clf.fit(x_trainp, y_trainp)
knn_clf.score(x_testp,y_testp)
# Out:
# 28 ms ± 395 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
knn_clf = KNeighborsClassifier()
knn_clf.fit(x_trainp, y_trainp)
knn_clf.score(x_testp,y_testp)
# Out:
# 0.9866666666666667

# %%
pca.explained_variance_ratio_
# Out:
# array([1.48905936e-01, 1.36187712e-01, 1.17945938e-01, 8.40997942e-02,
#        5.78241466e-02, 4.91691032e-02, 4.31598701e-02, 3.66137258e-02,
#        3.35324810e-02, 3.07880621e-02, 2.37234084e-02, 2.27269657e-02,
#        1.82186331e-02, 1.77385494e-02, 1.46710109e-02, 1.40971560e-02,
#        1.31858920e-02, 1.24813782e-02, 1.01771796e-02, 9.05617439e-03,
#        8.89538461e-03, 7.97123157e-03, 7.67493255e-03, 7.22903569e-03,
#        6.95888851e-03, 5.96081458e-03, 5.75614688e-03, 5.15157582e-03,
#        4.89539777e-03, 4.28887968e-03, 3.73606048e-03, 3.53274223e-03,
#        3.36683986e-03, 3.28029851e-03, 3.08320884e-03, 2.93778629e-03,
#        2.56588609e-03, 2.27742397e-03, 2.22277922e-03, 2.11430393e-03,
#        1.89909062e-03, 1.58652907e-03, 1.51159934e-03, 1.40578764e-03,
#        1.16622290e-03, 1.07492521e-03, 9.64053065e-04, 7.74630271e-04,
#        5.57211553e-04, 4.04330693e-04, 2.09916327e-04, 8.24797098e-05,
# ...

# %%
for i in range(62):
    if np.sum(pca.explained_variance_ratio_[:i]) > 0.95:
        print(i)
        break
# Out:
# 29

# %%
pca = PCA(2)
pca.fit(x)
x_pca = pca.transform(x)
for i in range(10):
    plt.scatter(x_pca[y ==i,0],x_pca[y==i,1],alpha= 0.6)
plt.show()
