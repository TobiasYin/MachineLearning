# %%
x = (0:100)/10

# %%
y = sin(x)

# %%
plot(x,y,type = "l")
# Out:
# plot without title

# %%
x <- rnorm(10000,0,1)
y <- rnorm(10000,0,1)
plot(x,y)
# Out:
# plot without title

# %%
rnorm(10,0,1)
# Out:
#  [1]  0.50576538 -2.23084695  0.61828299 -2.62559612  0.20208701  0.26162139
#  [7] -0.43219257 -0.07139447 -0.83068304 -1.54064027
